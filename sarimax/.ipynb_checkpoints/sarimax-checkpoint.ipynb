# %%
# !pip install numpy pandas matplotlib statsmodels
# Out:
# Requirement already satisfied: numpy in /Users/sho/.pyenv/versions/3.10.6/envs/lewagon/lib/python3.10/site-packages (1.24.2)
# Requirement already satisfied: pandas in /Users/sho/.pyenv/versions/3.10.6/envs/lewagon/lib/python3.10/site-packages (2.2.3)
# Requirement already satisfied: matplotlib in /Users/sho/.pyenv/versions/3.10.6/envs/lewagon/lib/python3.10/site-packages (3.5.3)
# Requirement already satisfied: statsmodels in /Users/sho/.pyenv/versions/3.10.6/envs/lewagon/lib/python3.10/site-packages (0.13.5)
# Requirement already satisfied: python-dateutil>=2.8.2 in /Users/sho/.pyenv/versions/3.10.6/envs/lewagon/lib/python3.10/site-packages (from pandas) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /Users/sho/.pyenv/versions/3.10.6/envs/lewagon/lib/python3.10/site-packages (from pandas) (2022.1)
# Requirement already satisfied: tzdata>=2022.7 in /Users/sho/.pyenv/versions/3.10.6/envs/lewagon/lib/python3.10/site-packages (from pandas) (2025.1)
# Requirement already satisfied: cycler>=0.10 in /Users/sho/.pyenv/versions/3.10.6/envs/lewagon/lib/python3.10/site-packages (from matplotlib) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in /Users/sho/.pyenv/versions/3.10.6/envs/lewagon/lib/python3.10/site-packages (from matplotlib) (4.38.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /Users/sho/.pyenv/versions/3.10.6/envs/lewagon/lib/python3.10/site-packages (from matplotlib) (1.4.4)
# Requirement already satisfied: packaging>=20.0 in /Users/sho/.pyenv/versions/3.10.6/envs/lewagon/lib/python3.10/site-packages (from matplotlib) (23.2)
# Requirement already satisfied: pillow>=6.2.0 in /Users/sho/.pyenv/versions/3.10.6/envs/lewagon/lib/python3.10/site-packages (from matplotlib) (9.5.0)
# Requirement already satisfied: pyparsing>=2.2.1 in /Users/sho/.pyenv/versions/3.10.6/envs/lewagon/lib/python3.10/site-packages (from matplotlib) (3.0.9)
# Requirement already satisfied: patsy>=0.5.2 in /Users/sho/.pyenv/versions/3.10.6/envs/lewagon/lib/python3.10/site-packages (from statsmodels) (0.5.3)
# Requirement already satisfied: scipy>=1.3 in /Users/sho/.pyenv/versions/3.10.6/envs/lewagon/lib/python3.10/site-packages (from statsmodels) (1.10.1)
# Requirement already satisfied: six in /Users/sho/.pyenv/versions/3.10.6/envs/lewagon/lib/python3.10/site-packages (from patsy>=0.5.2->statsmodels) (1.16.0)

# %%
# !pip install scipy
# Out:
# Requirement already satisfied: scipy in /Users/sho/.pyenv/versions/3.10.6/envs/lewagon/lib/python3.10/site-packages (1.10.1)
# Requirement already satisfied: numpy<1.27.0,>=1.19.5 in /Users/sho/.pyenv/versions/3.10.6/envs/lewagon/lib/python3.10/site-packages (from scipy) (1.24.2)

# %%
# !pip install pmdarima
# Out:
# Requirement already satisfied: pmdarima in /Users/sho/.pyenv/versions/3.10.6/envs/lewagon/lib/python3.10/site-packages (2.0.1)
# Requirement already satisfied: joblib>=0.11 in /Users/sho/.pyenv/versions/3.10.6/envs/lewagon/lib/python3.10/site-packages (from pmdarima) (1.1.1)
# Requirement already satisfied: Cython!=0.29.18,!=0.29.31,>=0.29 in /Users/sho/.pyenv/versions/3.10.6/envs/lewagon/lib/python3.10/site-packages (from pmdarima) (0.29.32)
# Requirement already satisfied: numpy>=1.21 in /Users/sho/.pyenv/versions/3.10.6/envs/lewagon/lib/python3.10/site-packages (from pmdarima) (1.24.2)
# Requirement already satisfied: pandas>=0.19 in /Users/sho/.pyenv/versions/3.10.6/envs/lewagon/lib/python3.10/site-packages (from pmdarima) (2.2.3)
# Requirement already satisfied: scikit-learn>=0.22 in /Users/sho/.pyenv/versions/3.10.6/envs/lewagon/lib/python3.10/site-packages (from pmdarima) (1.3.1)
# Requirement already satisfied: scipy>=1.3.2 in /Users/sho/.pyenv/versions/3.10.6/envs/lewagon/lib/python3.10/site-packages (from pmdarima) (1.10.1)
# Requirement already satisfied: statsmodels>=0.13.2 in /Users/sho/.pyenv/versions/3.10.6/envs/lewagon/lib/python3.10/site-packages (from pmdarima) (0.13.5)
# Requirement already satisfied: urllib3 in /Users/sho/.pyenv/versions/3.10.6/envs/lewagon/lib/python3.10/site-packages (from pmdarima) (2.2.1)
# Requirement already satisfied: setuptools!=50.0.0,>=38.6.0 in /Users/sho/.pyenv/versions/3.10.6/envs/lewagon/lib/python3.10/site-packages (from pmdarima) (75.8.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /Users/sho/.pyenv/versions/3.10.6/envs/lewagon/lib/python3.10/site-packages (from pandas>=0.19->pmdarima) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /Users/sho/.pyenv/versions/3.10.6/envs/lewagon/lib/python3.10/site-packages (from pandas>=0.19->pmdarima) (2022.1)
# Requirement already satisfied: tzdata>=2022.7 in /Users/sho/.pyenv/versions/3.10.6/envs/lewagon/lib/python3.10/site-packages (from pandas>=0.19->pmdarima) (2025.1)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /Users/sho/.pyenv/versions/3.10.6/envs/lewagon/lib/python3.10/site-packages (from scikit-learn>=0.22->pmdarima) (3.1.0)
# Requirement already satisfied: patsy>=0.5.2 in /Users/sho/.pyenv/versions/3.10.6/envs/lewagon/lib/python3.10/site-packages (from statsmodels>=0.13.2->pmdarima) (0.5.3)
# Requirement already satisfied: packaging>=21.3 in /Users/sho/.pyenv/versions/3.10.6/envs/lewagon/lib/python3.10/site-packages (from statsmodels>=0.13.2->pmdarima) (23.2)
# Requirement already satisfied: six in /Users/sho/.pyenv/versions/3.10.6/envs/lewagon/lib/python3.10/site-packages (from patsy>=0.5.2->statsmodels>=0.13.2->pmdarima) (1.16.0)

# %%
import numpy as np
import pandas as pd
import datetime

from pmdarima import auto_arima
from pmdarima.model_selection import train_test_split

from sklearn.metrics import mean_squared_error
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import mean_absolute_percentage_error

import warnings
warnings.simplefilter('ignore')

import matplotlib.pyplot as plt
plt.style.use('ggplot') #グラフスタイル
plt.rcParams['figure.figsize'] = [12, 9] #グラフサイズ
plt.rcParams['font.size'] = 14 #フォントサイズ

# %%
dataset ="AirPassengers.csv"
df = pd.read_csv(
    dataset,
    index_col='Month',  # 変数「Month」をインデックスに設定
    parse_dates=True     # インデックスを日付型に設定
)

# %%
train, test = train_test_split(df, test_size=12)

# %%
#
# グラフ（学習データとテストデータ）
#

fig, ax = plt.subplots()

# 学習データの描写
ax.plot(
    train.index,
    train.values,
    linestyle='-',
    label='train')

# テストデータの描写
ax.plot(
    test.index,
    test.values,
    linestyle='--',
    label='test',
    color='gray')

# 学習データとテスデータの間の縦線の描写
ax.axvline(
    datetime.datetime(1960,1,1),
    color='blue')

# 凡例表示
ax.legend()

plt.show()

# %%
#
# 予測モデルの学習（学習データ利用）
#

# 学習
arima_model = auto_arima(
    train,
    seasonal=True,
    m=12)

# 確認
print(arima_model.summary())
# Out:
#                                      SARIMAX Results
# ==========================================================================================
# Dep. Variable:                                  y   No. Observations:                  132
# Model:             SARIMAX(3, 0, 0)x(0, 1, 0, 12)   Log Likelihood                -447.843
# Date:                            Tue, 11 Mar 2025   AIC                            905.686
# Time:                                    09:30:30   BIC                            919.623
# Sample:                                01-01-1949   HQIC                           911.346
#                                      - 12-01-1959
# Covariance Type:                              opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# intercept      5.5341      2.007      2.757      0.006       1.600       9.468
# ar.L1          0.7049      0.095      7.393      0.000       0.518       0.892
# ar.L2          0.2574      0.131      1.968      0.049       0.001       0.514
# ar.L3         -0.1434      0.107     -1.338      0.181      -0.354       0.067
# sigma2       101.0969     12.818      7.887      0.000      75.974     126.220
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.00   Jarque-Bera (JB):                 2.83
# Prob(Q):                              0.96   Prob(JB):                         0.24
# Heteroskedasticity (H):               1.41   Skew:                            -0.14
# Prob(H) (two-sided):                  0.29   Kurtosis:                         3.70
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).

# %%
#
# 予測の実施
#

# 学習データ期間の予測
train_pred = arima_model.predict_in_sample()

# テストデータ期間の予測
test_pred = arima_model.predict(n_periods=12)

# %%
#
# 予測精度（テストデータ）
#

print('RMSE:\n',
      np.sqrt(mean_squared_error(
          test.Passengers, test_pred)))
print('MAE:\n',
      mean_absolute_error(
          test.Passengers, test_pred))
print('MAPE:\n',
      mean_absolute_percentage_error(
          test.Passengers, test_pred))
# Out:
# RMSE:
#  18.536468794391986
# MAE:
#  14.898208309463309
# MAPE:
#  0.03097561530304493

# %%
#
# グラフ（予測値と実測値）
#

fig, ax = plt.subplots()

# 実測値の描写
## 学習データ
ax.plot(
    train.index,
    train.Passengers,
    linestyle='-',
    label='actual(train)')

## テストデータ
ax.plot(
    test.index,
    test.Passengers,
    linestyle='--',
    label='actual(test)',
    color='gray')

# 予測値の描写
## 学習データ
ax.plot(
    train.index,
    train_pred,
    linestyle=':',
    color='c')

## テストデータ
ax.plot(
    test.index,
    test_pred,
    linestyle=':',
    label="predicted",
    color="c")

# 学習データとテスデータの間の縦線の描写
ax.axvline(
    datetime.datetime(1960,1,1),
    color='blue')

# 凡例表示
ax.legend()

plt.show()
